# %%
import sqlite3
from IPython.display import display
from aizynthfinder.reactiontree import ReactionTreeFromDict

def draw_tree_by_id(i: int, inverse=True):
    with sqlite3.connect('results.db') as conn:
        res = conn.execute(f'''
        SELECT tree_dict FROM routes
        WHERE id = {i}
        ''').fetchall()[0][0]
    
    if res:
        tree_dict = eval(res)
        tree = ReactionTreeFromDict(tree_dict).tree
        display(tree.to_image(inverse=inverse))
        
def draw_tree(tree_dict, inverse=True):
    if isinstance(tree_dict, str):
        tree_dict = eval(tree_dict)    
    tree = ReactionTreeFromDict(tree_dict).tree
    display(tree.to_image(inverse=inverse))

# %%
import pandas as pd

with sqlite3.connect('results.db') as conn:
    df = pd.read_sql('SELECT * FROM routes WHERE run_id=2 AND num_steps>0', conn)

df
# Out:
#       id                                  smi  solved  num_steps     score  \
# 0   1049       CCN(C)C(C)(C)C1=NN(CC(C)C)N=C1       1          3  0.986553
# 1   1050          CCCC(O)C1=CC=NC=C1C1N=COC1C       1          2  0.994040
# 2   1053       CCN(C1=NC(CO)=CC=C1Cl)C(C)(C)C       1          1  0.997629
# 3   1054       CN1CC(C1)C1=CC=C(Cl)C2=C1C=CO2       1          4  0.975000
# 4   1055        CCC(C)N(CC1=CN=CO1)CC1=CNC=C1       1          2  0.994040
# 5   1056      CC(OC1=CC=CN=C1C1=NC(C)=NO1)C#N       1          2  0.994040
# 6   1057     CC1=C(C)N(N=C1)C1=CC2=C(CCCN2)N1       1          9  0.950899
# 7   1060             CCCOC1CCC(CC1C)NCC(C)C#N       1          6  0.955960
# 8   1065           CCN1C=NC2=C1N=C1CCCCC1=C2C       1          4  0.975000
# 9   1070       CCCOC1=CN=C(N=C1)N(C)C1=CNC=C1       1          2  0.994040
# 10  1071      CC1CCC(CC(O)C2=NN(C)C(C)=N2)CC1       1          5  0.963447
# 11  1072           CCCN1N=C2C(C)N(CC)CCC2=C1O       1          6  0.955960
# 12  1073            CCC(C1CCCC1)N(C)CC1CNCCN1       1          4  0.975000
# 13  1076           CCC1CCC2=C1N=CN=C2NC1CCOC1       1          7  0.963447
# 14  1080    CC1=CN=C(CC(C)(C)NC2=CN=C(C)O2)S1       1          5  0.963447
# 15  1087           CCC1=C(CCO)NC2=C1SC(CO)=C2       1          5  0.975000
# 16  1091         CC1CCC(CC(C)(O)C2CN=CN2C)CC1       1          3  0.986553
# 17  1092     CCNC1=NNC(=O)N1C1=NC(C)=CC(C)=C1       1          3  0.986553
# 18  1093      CC(=O)NC1=NC=C(C)C=C1C1=CSN=C1O       1          2  0.994040
# 19  1101    CCC(C)(C)C(N)C1=C(NC)C(Cl)=CNC1=O       1          7  0.952371
# 20  1105       CC(C)CCOC1=C(SC(O)=N1)N1CCN=C1       1          3  0.986553
# 21  1107           CCC1(COCC(C)CO1)OC1CN(C)C1       1          8  0.950899
# 22  1108        CC1=NCCN2C=CC=C2N1CC(C)(C)C#N       1          5  0.963447
# 23  1116  CN1C=C2C(=N1)C(C1=CC=NN1)=C(C)C=C2O       1          4  0.975000
# 24  1122        CCC(CN(C)C1=CC=C(O)N=C1C#N)NC       1          9  0.955960
# 25  1133     CC(C)OC(C)C1COC(=N1)C1=CC(C)=NN1       1          8  0.952371
# 26  1135       CCC(N)C1=C(OC(C)(C)C(C)O)C=NS1       1          6  0.955960
# 27  1156       CCOC1=C(OC)C=NC2=C1NCC(C)(C)O2       1          6  0.955960
# 28  1170        CCC1=C(CC)C(CC2=NCCO2)=NNC1=O       1          4  0.986553
# 29  1187     CCC12NC(=O)N(C)C1=NC1=C2C=CC=C1C       1          5  0.963447
# 30  1201        CCC1CCC2=C(C1N)C1=C(CC=C1)N2C       1          4  0.975000
# 31  1213        CCC1C(CC2=C1N=C(CC1CC1)O2)C#N       1          6  0.955960
# 32  1222       CC1CC1(C)CC(N)C1=C(C)C=C(C)N1C       1          7  0.952371
# 33  1239    CCC1=CC2=C(CC(C2)(OCC#N)C(N)=O)S1       1          4  0.986553
# 34  1363       CC1=CN=C2CC3OC=NC3CC(C#N)C2=C1       1          5  0.963447
# 35  1446     CCNC1=C(C(O)C(C)(C)OC)C(=CS1)C#N       1          3  0.986553
# 36  1473    CC(C)(CO)NC1=C2CC3=C(C=NS3)C2=CN1       1          6  0.955960
# 37  1544            CCC1(O)CCC=CC=C1N1C=CN=C1       1          3  0.986553
# 38  1558  CC(C)(O)C1=C(C=C(CO)S1)C1=NC(O)=CN1       1          3  0.986553
# 39  1565     CC1CC(=O)N(CC(C)(C)C1N)C1=CSC=N1       1          7  0.952371
# 40  1650           CCC(C)CC(O)C1=CN=C(O)OC1=O       1          3  0.986553
# 41  1663    CCC1=NC(=O)C(Cl)=C(C)N1C1=NSC=C1C       1          4  0.975000
# 42  1669   CC1=C(C)C(OCC2=C(C)C(=O)C=CN2)=NS1       1          7  0.955960
# 43  1699           CCC(CO)C1NC2=CSC=C2C(C)C1N       1          3  0.986553
# 44  1738       CCCNC1=C(NC(=O)S1)OC(C)(C)CC#N       1          7  0.952371
# 45  1836    CCNC1=C(O)N(C(C)=C1)C1=NC(OC)=NS1       1          7  0.952371
# 46  1879     CC1=NC2=C(C=CC=N2)N=C1CC1=CN=NS1       1          5  0.963447
# 47  1952          CCC(O)CN1CCC2=C(C1)SC=C2CNC       1          3  0.986553
#
#                                             tree_dict  run_id
# 0   {'type': 'mol', 'hide': False, 'smiles': 'CCN(...       2
# 1   {'type': 'mol', 'hide': False, 'smiles': 'CCCC...       2
# 2   {'type': 'mol', 'hide': False, 'smiles': 'CCN(...       2
# 3   {'type': 'mol', 'hide': False, 'smiles': 'CN1C...       2
# 4   {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2
# 5   {'type': 'mol', 'hide': False, 'smiles': 'Cc1n...       2
# 6   {'type': 'mol', 'hide': False, 'smiles': 'Cc1c...       2
# 7   {'type': 'mol', 'hide': False, 'smiles': 'CCCO...       2
# 8   {'type': 'mol', 'hide': False, 'smiles': 'CCn1...       2
# 9   {'type': 'mol', 'hide': False, 'smiles': 'CCCO...       2
# 10  {'type': 'mol', 'hide': False, 'smiles': 'Cc1n...       2
# 11  {'type': 'mol', 'hide': False, 'smiles': 'CCCn...       2
# 12  {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2
# 13  {'type': 'mol', 'hide': False, 'smiles': 'CCC1...       2
# 14  {'type': 'mol', 'hide': False, 'smiles': 'Cc1n...       2
# 15  {'type': 'mol', 'hide': False, 'smiles': 'CCc1...       2
# 16  {'type': 'mol', 'hide': False, 'smiles': 'CC1C...       2
# 17  {'type': 'mol', 'hide': False, 'smiles': 'CCNc...       2
# 18  {'type': 'mol', 'hide': False, 'smiles': 'CC(=...       2
# 19  {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2
# 20  {'type': 'mol', 'hide': False, 'smiles': 'CC(C...       2
# 21  {'type': 'mol', 'hide': False, 'smiles': 'CCC1...       2
# 22  {'type': 'mol', 'hide': False, 'smiles': 'CC1=...       2
# 23  {'type': 'mol', 'hide': False, 'smiles': 'Cc1c...       2
# 24  {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2
# 25  {'type': 'mol', 'hide': False, 'smiles': 'Cc1c...       2
# 26  {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2
# 27  {'type': 'mol', 'hide': False, 'smiles': 'CCOc...       2
# 28  {'type': 'mol', 'hide': False, 'smiles': 'CCc1...       2
# 29  {'type': 'mol', 'hide': False, 'smiles': 'CCC1...       2
# 30  {'type': 'mol', 'hide': False, 'smiles': 'CCC1...       2
# 31  {'type': 'mol', 'hide': False, 'smiles': 'CCC1...       2
# 32  {'type': 'mol', 'hide': False, 'smiles': 'Cc1c...       2
# 33  {'type': 'mol', 'hide': False, 'smiles': 'CCc1...       2
# 34  {'type': 'mol', 'hide': False, 'smiles': 'Cc1c...       2
# 35  {'type': 'mol', 'hide': False, 'smiles': 'CCNc...       2
# 36  {'type': 'mol', 'hide': False, 'smiles': 'CC(C...       2
# 37  {'type': 'mol', 'hide': False, 'smiles': 'CCC1...       2
# 38  {'type': 'mol', 'hide': False, 'smiles': 'CC(C...       2
# 39  {'type': 'mol', 'hide': False, 'smiles': 'CC1C...       2
# 40  {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2
# 41  {'type': 'mol', 'hide': False, 'smiles': 'CCc1...       2
# 42  {'type': 'mol', 'hide': False, 'smiles': 'Cc1s...       2
# 43  {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2
# 44  {'type': 'mol', 'hide': False, 'smiles': 'CCCN...       2
# 45  {'type': 'mol', 'hide': False, 'smiles': 'CCNc...       2
# 46  {'type': 'mol', 'hide': False, 'smiles': 'Cc1n...       2
# 47  {'type': 'mol', 'hide': False, 'smiles': 'CCC(...       2

# %%
draw_tree_by_id(1952)
# Out:
# <PIL.Image.Image image mode=RGB size=1296x463>

# %%
# solved_both_id = [3, 4, 7, 9, 10, 19, 24, 25, 30, 41, 46, 47, 59,
#                  61, 62, 70, 87, 124, 167, 193, 317]

# %%
import gzip
import json
import pandas as pd

# %%
with gzip.open('data/gdb_1000_az.json.gz', 'rb') as f:
    res = json.load(f)
    res = pd.DataFrame(res['data'])

# %%
res[res.is_solved]
# Out:
#      index                              target  search_time  \
# 0        0         CC(CO)Nc1nscc1C1(C)OCC(C)O1   900.113922
# 2        2        CCN(C)C(C)(C)c1cnn(CC(C)C)n1   900.305469
# 3        3            CCCC(O)c1ccncc1C1N=COC1C   542.390052
# 6        6         CCN(c1nc(CO)ccc1Cl)C(C)(C)C   900.823971
# 7        7          CN1CC(c2ccc(Cl)c3occc23)C1   900.288965
# 8        8        CCC(C)N(Cc1cc[nH]c1)Cc1cnco1   644.395988
# 9        9         Cc1noc(-c2ncccc2OC(C)C#N)n1   900.146192
# 10      10      Cc1cnn(-c2cc3c([nH]2)CCCN3)c1C   900.085623
# 11      11              CCC(C)CC1=CCOc2cnccc21   900.071202
# 13      13            CCCOC1CCC(NCC(C)C#N)CC1C   900.145291
# 14      14              CCCOc1cnc2c(n1)C(C)CC2   901.099131
# 18      18          CCn1cnc2c(C)c3c(nc21)CCCC3   900.236979
# 23      23        CCCOc1cnc(N(C)c2cc[nH]c2)nc1   900.043969
# 24      24         Cc1nc(C(O)CC2CCC(C)CC2)nn1C   900.176552
# 25      25            CCCn1nc2c(c1O)CCN(CC)C2C   900.333635
# 26      26           CCC(C1CCCC1)N(C)CC1CNCCN1   900.107006
# 29      29           CCC1CCc2c(NC3CCOC3)ncnc21   900.289053
# 33      33       Cc1ncc(NC(C)(C)Cc2ncc(C)s2)o1   900.668078
# 37      37         CCC(OCC1CC(C)CO1)c1cnc(C)o1   900.382147
# 40      40          CCc1c(CCO)[nH]c2cc(CO)sc12   900.080730
# 42      42  CC(O)C1COC(C)(C(C)(C(=O)O)C(C)C)O1   900.394677
# 45      45    CCNc1n[nH]c(=O)n1-c1cc(C)cc(C)n1   900.020335
# 46      46         CC(=O)Nc1ncc(C)cc1-c1csnc1O   900.640478
# 47      47           CCOc1nscc1CCC1COC(C)(C)O1   900.096789
# 51      51       CC(O)C(C)Oc1cc(CN(C)C(C)C)on1   900.070365
# 63      63              CC1(OCC#N)CCCC1COC1CC1   900.213884
# 64      64      CC1CCC(O)(CC#N)C1CC(C)C(F)(F)F   901.530325
# 69      69     Cc1cc(O)c2cn(C)nc2c1-c1ccn[nH]1   900.009462
# 75      75          CCC(CN(C)c1ccc(O)nc1C#N)NC   900.067865
# 76      76    CC1(c2ncc[nH]2)CCN(c2nc(O)cs2)C1   900.228858
# 86      86   Cc1cc(C2=NC(C(C)OC(C)C)CO2)[nH]n1   900.104844
# 87      87         CCC(C)(Oc1ccnc(O)c1NC)C(C)O   900.207072
# 109    109         CCOc1c(OC)cnc2c1NCC(C)(C)O2   900.090450
# 123    123      CCc1c(CC2=NCCO2)n[nH]c(=O)c1CC   900.135838
# 124    124      CCNc1c(C)[nH]c(OC(CC)C(C)O)c1C   900.017972
# 126    126      Cc1cc2scnc2nc1-c1sc(=O)[nH]c1C   900.269315
# 140    140     CCC12NC(=O)N(C)C1=Nc1c(C)cccc12   803.600093
# 154    154         CCC1CCc2c(c3c(n2C)CC=C3)C1N   900.096195
# 178    178              CCC1OC(C)CC1(CC)C(N)=O   900.023713
# 192    192     CCc1cc2c(s1)CC(OCC#N)(C(N)=O)C2   900.273613
# 202    202         CC(C)C(C)(CO)Oc1c(CCO)ccn1C   900.100994
# 205    205            Cc1cc2occc2nc1CC1CC(C)O1   900.114054
# 228    228           CC(N)COc1csc2ccc3cnsc3c12   900.045189
# 399    399        CCNc1scc(C#N)c1C(O)C(C)(C)OC   900.312793
# 463    463     CCNc1cc(OC)c(CC(C)(C)C)[nH]c1=N   901.025361
# 518    518      CC1CC(=O)N(c2cscn2)CC(C)(C)C1N   900.281379
# 527    527         CC(CO)OCC1CCC(C2(C)CCCC2)O1   900.180127
# 616    616      CCc1nc(=O)c(Cl)c(C)n1-c1nscc1C   509.201101
# 640    640           CCC1OCCC(OCC2CCC(N)C2)C1C   900.230486
# 652    652            CCC(CO)C1Nc2cscc2C(C)C1N   900.919789
# 829    829         CCCNc1cc(C#N)n(C(C)(C)C)c1O   900.060219
# 832    832             Cc1nc2ncccc2nc1Cc1cnns1   900.663344
# 905    905           CCC(O)CN1CCc2c(CNC)csc2C1   900.268143
#
#      first_solution_time  first_solution_iteration  number_of_nodes  \
# 0              37.553378                        90            13128
# 2              11.942578                        15             8798
# 3               8.267072                        17             5420
# 6               0.408946                         1             7743
# 7             373.220643                      1164            13693
# 8               0.402609                         1             6179
# 9               1.482225                         4             7999
# 10            452.458269                       968             7779
# 11            670.757582                      2016             8011
# 13              0.333926                         1            11670
# 14              0.105497                         1             8279
# 18            387.040286                      1090            11011
# 23              2.827318                         9            14589
# 24            295.328332                       695             9111
# 25              0.956750                         2            14483
# 26              4.830070                         9            11544
# 29             51.036774                        85             6567
# 33            248.932227                       759            10409
# 37             65.854964                       113             8220
# 40            336.999990                      1116            15735
# 42            438.767560                      1101            10405
# 45              2.560337                         4             9460
# 46             38.731183                        40             6715
# 47            307.259141                       817            11296
# 51              9.923963                         6             7938
# 63            788.474887                      2352            13594
# 64            113.374319                       230             9504
# 69            681.476385                      2748            15448
# 75              0.763300                         1            10933
# 76            783.845550                      2069            10922
# 86            228.690719                       532            10943
# 87            651.266849                      1710            10063
# 109           333.748639                       949            11164
# 123            98.225660                       230            11881
# 124           117.370886                       222            10712
# 126            70.664692                       100             6507
# 140            10.206971                         8             5444
# 154             2.622541                         4             8018
# 178           290.902732                       780            11846
# 192            26.727112                        71            13640
# 202           114.000859                       288            13519
# 205           112.850237                       270            10922
# 228           358.903951                      1049            12960
# 399            28.843389                        46             9934
# 463           341.336571                       864            10418
# 518           544.406868                      1282             8585
# 527           168.073153                       381            11965
# 616            20.725554                        21             2283
# 640           178.358876                       385            10584
# 652           152.145891                       329            11504
# 829           422.418103                      1046             9800
# 832           722.934162                      1582             8330
# 905            12.019567                        27            14336
#
#      max_transforms  max_children  number_of_routes  number_of_solved_routes  \
# 0                 6            33              4335                       89
# 2                 6            20              2845                       52
# 3                 6            22              1737                       49
# 6                 6            20              2897                     1065
# 7                 6            26              4277                       10
# 8                 6            25              2585                      461
# 9                 6            37              2774                      959
# 10                6            22              2426                        4
# 11                6            17              3432                        6
# 13                6            38              2379                      208
# 14                6            29              2758                      650
# 18                6            21              3093                        9
# 23                6            39              3731                      382
# 24                6            25              3303                        6
# 25                6            30              3921                       13
# 26                6            50              3748                      115
# 29                6            23              2589                       27
# 33                6            27              3761                       35
# 37                6            26              1843                       88
# 40                6            31              5042                       12
# 42                6            48              3682                        1
# 45                6            25              2854                       25
# 46                6            27              2189                      220
# 47                6            46              3561                       16
# 51                6            30              2067                      171
# 63                6            33              4172                       16
# 64                6            33              2856                        9
# 69                6            33              4140                        4
# 75                6            53              2886                      198
# 76                6            35              2690                        2
# 86                6            42              3467                       18
# 87                6            20              2600                        1
# 109               6            22              2993                        8
# 123               6            30              3142                        9
# 124               6            22              3434                       25
# 126               6            24              1757                       42
# 140               6            21              2674                       46
# 154               6            29              2574                       84
# 178               6            25              4708                        2
# 192               6            43              3293                       54
# 202               6            41              4348                       12
# 205               6            45              3608                       17
# 228               6            49              3636                       14
# 399               6            43              4280                       81
# 463               6            21              2900                        6
# 518               6            23              2797                        3
# 527               6            46              4099                        5
# 616               6            53               855                        3
# 640               6            42              2698                        8
# 652               6            26              4002                        9
# 829               6            24              2553                        3
# 832               6            41              2725                        2
# 905               6            29              3687                       74
#
#      ...  number_of_steps  number_of_precursors  \
# 0    ...                3                     4
# 2    ...                3                     4
# 3    ...                2                     3
# 6    ...                2                     2
# 7    ...                4                     4
# 8    ...                2                     3
# 9    ...                2                     3
# 10   ...                6                     4
# 11   ...                5                     5
# 13   ...                4                     6
# 14   ...                2                     3
# 18   ...                4                     4
# 23   ...                3                     4
# 24   ...                5                     6
# 25   ...                4                     4
# 26   ...                4                     2
# 29   ...                3                     5
# 33   ...                5                     5
# 37   ...                4                     5
# 40   ...                4                     3
# 42   ...                3                     3
# 45   ...                3                     4
# 46   ...                2                     3
# 47   ...                4                     5
# 51   ...                4                     5
# 63   ...                3                     4
# 64   ...                2                     3
# 69   ...                6                     5
# 75   ...                4                     3
# 76   ...                5                     5
# 86   ...                4                     5
# 87   ...                5                     5
# 109  ...                5                     5
# 123  ...                3                     4
# 124  ...                5                     5
# 126  ...                3                     4
# 140  ...                2                     3
# 154  ...                4                     5
# 178  ...                4                     4
# 192  ...                3                     5
# 202  ...                3                     4
# 205  ...                3                     4
# 228  ...                4                     4
# 399  ...                3                     3
# 463  ...                4                     4
# 518  ...                4                     4
# 527  ...                3                     4
# 616  ...                4                     5
# 640  ...                4                     4
# 652  ...                3                     3
# 829  ...                6                     6
# 832  ...                5                     4
# 905  ...                3                     3
#
#      number_of_precursors_in_stock  \
# 0                                4
# 2                                4
# 3                                3
# 6                                2
# 7                                4
# 8                                3
# 9                                3
# 10                               4
# 11                               5
# 13                               6
# 14                               3
# 18                               4
# 23                               4
# 24                               6
# 25                               4
# 26                               2
# 29                               5
# 33                               5
# 37                               5
# 40                               3
# 42                               3
# 45                               4
# 46                               3
# 47                               5
# 51                               5
# 63                               4
# 64                               3
# 69                               5
# 75                               3
# 76                               5
# 86                               5
# 87                               5
# 109                              5
# 123                              4
# 124                              5
# 126                              4
# 140                              3
# 154                              5
# 178                              4
# 192                              5
# 202                              4
# 205                              4
# 228                              4
# 399                              3
# 463                              4
# 518                              4
# 527                              4
# 616                              5
# 640                              4
# 652                              3
# 829                              6
# 832                              4
# 905                              3
#
#                                    precursors_in_stock  \
# 0                CC(O)CO, CC(N)CO, CC(=O)Cl, Clc1ccsn1
# 2    CC(C)CBr, C[Si](C)(C)N=[N+]=[N-], C#CC(C)(C)Cl...
# 3                     CCCC=O, CC=O, [C-]#[N+]Cc1cccnc1
# 6                     CCNC(C)(C)C, O=Cc1ccc(Cl)c(Br)n1
# 7    COC(CO)OC, O=C1CCC(=O)N1Cl, C=O, Fc1cccc(C2CNC...
# 8                   O=Cc1cnco1, CCC(C)N, O=Cc1cc[nH]c1
# 9                  CC(N)=NO, O=C(O)c1ncccc1F, CC(O)C#N
# 10   Nc1cccnc1I, CCOC(=O)c1n[nH]c(C)c1C, CCC(=O)OC(...
# 11   Oc1cnccc1Cl, CC1(C)OB(B2OC(C)(C)C(C)(C)O2)OC1(...
# 13   CCCO, CC(C#N)C(=O)O, O=C1CCC(N(Cc2ccccc2)Cc2cc...
# 14               CCCO, O=C1CCC(=O)N1Cl, CC1CCc2nccnc21
# 18   CCOC(OCC)OCC, CCN, O=C1CCC(=O)N1Br, Cc1c(N)cnc...
# 23       CI, CCCBr, Nc1ncc(O)cn1, CCOC(=O)c1[nH]ccc1Br
# 24   CI, NN, CCOC(=O)C(=O)OCC, CC1CCC(CBr)CC1, CC(C...
# 25                 CCCNN, CCOC(=O)OCC, CCI, CC1NCCCC1O
# 26                        O=Cc1cnccn1, CCC(NC)c1ccccc1
# 29   NC1CCOC1, O=C1CCC(=O)N1Cl, CC(=O)O, CCC1CCCC1=...
# 33   CI, CCOC(=O)CNC(C)=O, CC(C)(N)CC(N)=O, COc1ccc...
# 37   O=C1CCC(=O)N1Br, CCC=O, Cc1ncco1, C=CCC(C)CCl,...
# 40             CCCC(=O)CC(=O)OC, NN, COC(=O)c1cc(F)cs1
# 42              CC(O)C(O)CO, COC(=O)C(C(C)=O)C(C)C, CI
# 45    CCN, CSC(=N)N, Cc1cc(C)nc(N)c1, NNC(=O)Oc1ccccc1
# 46           CC(=O)Nc1ncc(C)cc1Br, COB(OC)OC, Oc1ccsn1
# 47            COC(C)(C)OC, OCC1CO1, CCO, CI, Clc1ccsn1
# 51   O=C1CCC(=O)N1Br, CC(=O)C(C)Cl, Cc1cc(O)no1, C=...
# 63                     N#CCBr, CI, O=C1CCCC1CO, OC1CC1
# 64                 CC#N, CC1CCC(=O)C1, CC(C=O)C(F)(F)F
# 69   OB(O)c1ccn[nH]1, CI, CN(C)C=O, O=C1CCC(=O)N1Br...
# 75                COc1ccc(Br)c(C#N)n1, C=O, CCC(C#N)NC
# 76   O=C(O)CCl, CN(C)S(=O)(=O)Cl, Clc1ncc[nH]1, O=C...
# 86   NN, CC(C)I, CC(O)C(N)C(=O)O, CCOC(C)=O, CC(=O)C#N
# 87   CCBr, CC(=O)C(C)O, BrCc1ccccc1, O=CO, COc1nccc...
# 109  O=C1CCC(=O)N1Cl, CC(C)(O)CN, CO, CCO, Fc1cncc(...
# 123          NCCO, CC#N, CCc1c(Cl)nnc(Cl)c1CC, CC(=O)O
# 124  O=C1CCC(=O)N1Cl, O=C(O)c1ccc([N+](=O)[O-])cc1,...
# 126  Cc1cnc2nc(Cl)sc2c1, CCCC[Sn](Cl)(CCCC)CCCC, O=...
# 140                  C=O, CCC1NC(=O)NC1=O, Cc1ccccc1NN
# 154            NO, CI, CCI, NC1=CC(=O)CCC1, O=C1CC=CC1
# 178                         CO, C=CCI, CCI, CCC(O)CC#N
# 192  COCBr, O=C1CCC(=O)N1Br, CCc1ccc(C)s1, N#CCBr, ...
# 202      Cn1cccc1Cl, CC(C)C(C)(O)C(=O)O, CS(C)=O, O=CO
# 205  O=C1CCC(=O)N1Br, C=CCC(C)O, COC(CBr)OC, Cc1cc(...
# 228    CC(N)CO, O=C1CCC(=O)N1Br, Brc1cnsc1, C=Cc1cccs1
# 399        CC=O, COC(C)(C)CO, N#Cc1csc([N+](=O)[O-])c1
# 463  CCN, CC(C)(C)[Mg]Cl, CN(C)C=O, COc1c[nH]c(=N)c...
# 518  Clc1cscn1, c1ccc(CNCc2ccccc2)cc1, CC1CC(=O)CC(...
# 527  CC(O)CO, O=C1CCC(=O)N1Br, C=CCC[Mg]Br, CC1(C=O...
# 616  CI, CI, Brc1ccsn1, Cc1cc(=O)nc(C)[nH]1, O=C1CC...
# 640  BrC(Br)(Br)Br, CC(C)(C)OC(=O)NC1CCC(CO)C1, C=O...
# 652   CC=C[N+](=O)[O-], CCC(CO)CO, O=[N+]([O-])c1ccsc1
# 829  CCCN, O=C1CCC(=O)N1Br, O=C=NS(=O)(=O)Cl, OCc1c...
# 832       C1COCCO1, Cc1nnsc1C=O, CC(=O)C=O, Nc1cccnc1N
# 905   CN, CCC1CO1, CC(C)(C)OC(=O)N1CCc2c(C(=O)O)csc2C1
#
#      precursors_not_in_stock  \
# 0
# 2
# 3
# 6
# 7
# 8
# 9
# 10
# 11
# 13
# 14
# 18
# 23
# 24
# 25
# 26
# 29
# 33
# 37
# 40
# 42
# 45
# 46
# 47
# 51
# 63
# 64
# 69
# 75
# 76
# 86
# 87
# 109
# 123
# 124
# 126
# 140
# 154
# 178
# 192
# 202
# 205
# 228
# 399
# 463
# 518
# 527
# 616
# 640
# 652
# 829
# 832
# 905
#
#                                precursors_availability policy_used_counts  \
# 0          molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 13127}
# 2          molport_7d;molport_7d;molport_7d;molport_7d    {'uspto': 8797}
# 3                     molport_7d;molport_7d;molport_7d    {'uspto': 5419}
# 6                                molport_7d;molport_7d    {'uspto': 7742}
# 7          molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 13692}
# 8                     molport_7d;molport_7d;molport_7d    {'uspto': 6178}
# 9                     molport_7d;molport_7d;molport_7d    {'uspto': 7998}
# 10         molport_7d;molport_7d;molport_7d;molport_7d    {'uspto': 7778}
# 11   molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 8010}
# 13   molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 11669}
# 14                    molport_7d;molport_7d;molport_7d    {'uspto': 8278}
# 18         molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 11010}
# 23         molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 14588}
# 24   molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 9110}
# 25         molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 14482}
# 26                               molport_7d;molport_7d   {'uspto': 11543}
# 29   molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 6566}
# 33   molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 10408}
# 37   molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 8219}
# 40                    molport_7d;molport_7d;molport_7d   {'uspto': 15734}
# 42                    molport_7d;molport_7d;molport_7d   {'uspto': 10404}
# 45         molport_7d;molport_7d;molport_7d;molport_7d    {'uspto': 9459}
# 46                    molport_7d;molport_7d;molport_7d    {'uspto': 6714}
# 47   molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 11295}
# 51   molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 7937}
# 63         molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 13593}
# 64                    molport_7d;molport_7d;molport_7d    {'uspto': 9503}
# 69   molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 15447}
# 75                    molport_7d;molport_7d;molport_7d   {'uspto': 10932}
# 76   molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 10921}
# 86   molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 10942}
# 87   molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 10062}
# 109  molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 11163}
# 123        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 11880}
# 124  molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 10711}
# 126        molport_7d;molport_7d;molport_7d;molport_7d    {'uspto': 6506}
# 140                   molport_7d;molport_7d;molport_7d    {'uspto': 5443}
# 154  molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 8017}
# 178        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 11845}
# 192  molport_7d;molport_7d;molport_7d;molport_7d;mo...   {'uspto': 13639}
# 202        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 13518}
# 205        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 10921}
# 228        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 12959}
# 399                   molport_7d;molport_7d;molport_7d    {'uspto': 9933}
# 463        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 10417}
# 518        molport_7d;molport_7d;molport_7d;molport_7d    {'uspto': 8584}
# 527        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 11964}
# 616  molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 2282}
# 640        molport_7d;molport_7d;molport_7d;molport_7d   {'uspto': 10583}
# 652                   molport_7d;molport_7d;molport_7d   {'uspto': 11503}
# 829  molport_7d;molport_7d;molport_7d;molport_7d;mo...    {'uspto': 9799}
# 832        molport_7d;molport_7d;molport_7d;molport_7d    {'uspto': 8329}
# 905                   molport_7d;molport_7d;molport_7d   {'uspto': 14335}
#
#                                              profiling  \
# 0    {'expansion_calls': 8916, 'reactants_generatio...
# 2    {'expansion_calls': 5991, 'reactants_generatio...
# 3    {'expansion_calls': 3702, 'reactants_generatio...
# 6    {'expansion_calls': 5338, 'reactants_generatio...
# 7    {'expansion_calls': 9418, 'reactants_generatio...
# 8    {'expansion_calls': 3837, 'reactants_generatio...
# 9    {'expansion_calls': 5750, 'reactants_generatio...
# 10   {'expansion_calls': 5361, 'reactants_generatio...
# 11   {'expansion_calls': 4617, 'reactants_generatio...
# 13   {'expansion_calls': 9521, 'reactants_generatio...
# 14   {'expansion_calls': 5887, 'reactants_generatio...
# 18   {'expansion_calls': 8049, 'reactants_generatio...
# 23   {'expansion_calls': 10883, 'reactants_generati...
# 24   {'expansion_calls': 5888, 'reactants_generatio...
# 25   {'expansion_calls': 10572, 'reactants_generati...
# 26   {'expansion_calls': 7879, 'reactants_generatio...
# 29   {'expansion_calls': 4163, 'reactants_generatio...
# 33   {'expansion_calls': 6756, 'reactants_generatio...
# 37   {'expansion_calls': 6377, 'reactants_generatio...
# 40   {'expansion_calls': 10724, 'reactants_generati...
# 42   {'expansion_calls': 6792, 'reactants_generatio...
# 45   {'expansion_calls': 6708, 'reactants_generatio...
# 46   {'expansion_calls': 4678, 'reactants_generatio...
# 47   {'expansion_calls': 7809, 'reactants_generatio...
# 51   {'expansion_calls': 6222, 'reactants_generatio...
# 63   {'expansion_calls': 9486, 'reactants_generatio...
# 64   {'expansion_calls': 6709, 'reactants_generatio...
# 69   {'expansion_calls': 11310, 'reactants_generati...
# 75   {'expansion_calls': 8072, 'reactants_generatio...
# 76   {'expansion_calls': 8256, 'reactants_generatio...
# 86   {'expansion_calls': 7496, 'reactants_generatio...
# 87   {'expansion_calls': 7487, 'reactants_generatio...
# 109  {'expansion_calls': 8188, 'reactants_generatio...
# 123  {'expansion_calls': 8748, 'reactants_generatio...
# 124  {'expansion_calls': 7393, 'reactants_generatio...
# 126  {'expansion_calls': 4823, 'reactants_generatio...
# 140  {'expansion_calls': 2864, 'reactants_generatio...
# 154  {'expansion_calls': 5485, 'reactants_generatio...
# 178  {'expansion_calls': 7146, 'reactants_generatio...
# 192  {'expansion_calls': 10462, 'reactants_generati...
# 202  {'expansion_calls': 9240, 'reactants_generatio...
# 205  {'expansion_calls': 7345, 'reactants_generatio...
# 228  {'expansion_calls': 9339, 'reactants_generatio...
# 399  {'expansion_calls': 5730, 'reactants_generatio...
# 463  {'expansion_calls': 7540, 'reactants_generatio...
# 518  {'expansion_calls': 5832, 'reactants_generatio...
# 527  {'expansion_calls': 7950, 'reactants_generatio...
# 616  {'expansion_calls': 1445, 'reactants_generatio...
# 640  {'expansion_calls': 7954, 'reactants_generatio...
# 652  {'expansion_calls': 7520, 'reactants_generatio...
# 829  {'expansion_calls': 7277, 'reactants_generatio...
# 832  {'expansion_calls': 5682, 'reactants_generatio...
# 905  {'expansion_calls': 10675, 'reactants_generati...
#
#                                             stock_info  \
# 0    {'CC(O)CO': ['molport_7d'], 'CC(N)CO': ['molpo...
# 2    {'CC(C)CBr': ['molport_7d'], 'C[Si](C)(C)N=[N+...
# 3    {'CCCC=O': ['molport_7d'], 'CC=O': ['molport_7...
# 6    {'CCNC(C)(C)C': ['molport_7d'], 'O=Cc1ccc(Cl)c...
# 7    {'COC(CO)OC': ['molport_7d'], 'O=C1CCC(=O)N1Cl...
# 8    {'O=Cc1cnco1': ['molport_7d'], 'CCC(C)N': ['mo...
# 9    {'CC(N)=NO': ['molport_7d'], 'O=C(O)c1ncccc1F'...
# 10   {'Nc1cccnc1I': ['molport_7d'], 'CCOC(=O)c1n[nH...
# 11   {'Oc1cnccc1Cl': ['molport_7d'], 'CC1(C)OB(B2OC...
# 13   {'CCCO': ['molport_7d'], 'CC(C#N)C(=O)O': ['mo...
# 14   {'CCCO': ['molport_7d'], 'O=C1CCC(=O)N1Cl': ['...
# 18   {'CCOC(OCC)OCC': ['molport_7d'], 'CCN': ['molp...
# 23   {'CI': ['molport_7d'], 'CCCBr': ['molport_7d']...
# 24   {'CI': ['molport_7d'], 'NN': ['molport_7d'], '...
# 25   {'CCCNN': ['molport_7d'], 'CCOC(=O)OCC': ['mol...
# 26   {'O=Cc1cnccn1': ['molport_7d'], 'CCC(NC)c1cccc...
# 29   {'NC1CCOC1': ['molport_7d'], 'O=C1CCC(=O)N1Cl'...
# 33   {'CI': ['molport_7d'], 'CCOC(=O)CNC(C)=O': ['m...
# 37   {'O=C1CCC(=O)N1Br': ['molport_7d'], 'CCC=O': [...
# 40   {'CCCC(=O)CC(=O)OC': ['molport_7d'], 'NN': ['m...
# 42   {'CC(O)C(O)CO': ['molport_7d'], 'COC(=O)C(C(C)...
# 45   {'CCN': ['molport_7d'], 'CSC(=N)N': ['molport_...
# 46   {'CC(=O)Nc1ncc(C)cc1Br': ['molport_7d'], 'COB(...
# 47   {'COC(C)(C)OC': ['molport_7d'], 'OCC1CO1': ['m...
# 51   {'O=C1CCC(=O)N1Br': ['molport_7d'], 'CC(=O)C(C...
# 63   {'N#CCBr': ['molport_7d'], 'CI': ['molport_7d'...
# 64   {'CC#N': ['molport_7d'], 'CC1CCC(=O)C1': ['mol...
# 69   {'OB(O)c1ccn[nH]1': ['molport_7d'], 'CI': ['mo...
# 75   {'COc1ccc(Br)c(C#N)n1': ['molport_7d'], 'C=O':...
# 76   {'O=C(O)CCl': ['molport_7d'], 'CN(C)S(=O)(=O)C...
# 86   {'NN': ['molport_7d'], 'CC(C)I': ['molport_7d'...
# 87   {'CCBr': ['molport_7d'], 'CC(=O)C(C)O': ['molp...
# 109  {'O=C1CCC(=O)N1Cl': ['molport_7d'], 'CC(C)(O)C...
# 123  {'NCCO': ['molport_7d'], 'CC#N': ['molport_7d'...
# 124  {'O=C1CCC(=O)N1Cl': ['molport_7d'], 'O=C(O)c1c...
# 126  {'Cc1cnc2nc(Cl)sc2c1': ['molport_7d'], 'CCCC[S...
# 140  {'C=O': ['molport_7d'], 'CCC1NC(=O)NC1=O': ['m...
# 154  {'NO': ['molport_7d'], 'CI': ['molport_7d'], '...
# 178  {'CO': ['molport_7d'], 'C=CCI': ['molport_7d']...
# 192  {'COCBr': ['molport_7d'], 'O=C1CCC(=O)N1Br': [...
# 202  {'Cn1cccc1Cl': ['molport_7d'], 'CC(C)C(C)(O)C(...
# 205  {'O=C1CCC(=O)N1Br': ['molport_7d'], 'C=CCC(C)O...
# 228  {'CC(N)CO': ['molport_7d'], 'O=C1CCC(=O)N1Br':...
# 399  {'CC=O': ['molport_7d'], 'COC(C)(C)CO': ['molp...
# 463  {'CCN': ['molport_7d'], 'CC(C)(C)[Mg]Cl': ['mo...
# 518  {'Clc1cscn1': ['molport_7d'], 'c1ccc(CNCc2cccc...
# 527  {'CC(O)CO': ['molport_7d'], 'O=C1CCC(=O)N1Br':...
# 616  {'CI': ['molport_7d'], 'Brc1ccsn1': ['molport_...
# 640  {'BrC(Br)(Br)Br': ['molport_7d'], 'CC(C)(C)OC(...
# 652  {'CC=C[N+](=O)[O-]': ['molport_7d'], 'CCC(CO)C...
# 829  {'CCCN': ['molport_7d'], 'O=C1CCC(=O)N1Br': ['...
# 832  {'C1COCCO1': ['molport_7d'], 'Cc1nnsc1C=O': ['...
# 905  {'CN': ['molport_7d'], 'CCC1CO1': ['molport_7d...
#
#                                                  trees
# 0    [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 2    [{'type': 'mol', 'hide': False, 'smiles': 'CCN...
# 3    [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 6    [{'type': 'mol', 'hide': False, 'smiles': 'CCN...
# 7    [{'type': 'mol', 'hide': False, 'smiles': 'CN1...
# 8    [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 9    [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 10   [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 11   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 13   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 14   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 18   [{'type': 'mol', 'hide': False, 'smiles': 'CCn...
# 23   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 24   [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 25   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 26   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 29   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 33   [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 37   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 40   [{'type': 'mol', 'hide': False, 'smiles': 'CCc...
# 42   [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 45   [{'type': 'mol', 'hide': False, 'smiles': 'CCN...
# 46   [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 47   [{'type': 'mol', 'hide': False, 'smiles': 'CCO...
# 51   [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 63   [{'type': 'mol', 'hide': False, 'smiles': 'CC1...
# 64   [{'type': 'mol', 'hide': False, 'smiles': 'CC1...
# 69   [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 75   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 76   [{'type': 'mol', 'hide': False, 'smiles': 'CC1...
# 86   [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 87   [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 109  [{'type': 'mol', 'hide': False, 'smiles': 'CCO...
# 123  [{'type': 'mol', 'hide': False, 'smiles': 'CCc...
# 124  [{'type': 'mol', 'hide': False, 'smiles': 'CCN...
# 126  [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 140  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 154  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 178  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 192  [{'type': 'mol', 'hide': False, 'smiles': 'CCc...
# 202  [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 205  [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 228  [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 399  [{'type': 'mol', 'hide': False, 'smiles': 'CCN...
# 463  [{'type': 'mol', 'hide': False, 'smiles': 'CCN...
# 518  [{'type': 'mol', 'hide': False, 'smiles': 'CC1...
# 527  [{'type': 'mol', 'hide': False, 'smiles': 'CC(...
# 616  [{'type': 'mol', 'hide': False, 'smiles': 'CCc...
# 640  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 652  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 829  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
# 832  [{'type': 'mol', 'hide': False, 'smiles': 'Cc1...
# 905  [{'type': 'mol', 'hide': False, 'smiles': 'CCC...
#
# [53 rows x 22 columns]

# %%
for t in res[res.is_solved].iloc[51]['trees']:
    draw_tree(t, inverse=True)
# Out:
# <PIL.Image.Image image mode=RGB size=2192x677>
# <PIL.Image.Image image mode=RGB size=2192x625>
